# %% [markdown]
# <a href="https://colab.research.google.com/github/wesleyclzns/notebook-bcc-ufabc-2021.3/blob/main/MegaSenaProjetoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este notebook servirá como template para o Projeto Final de BCC
#
# A ideia do projeto final é você usar os conceitos e métodos aprendidos durante o curso para criar um programa/notebook que resolva um problema de seu interesse.
#
# O projeto final deverá ser entregue como o link para um notebook Colab.
#
# Para facilitar a compreensão, por favor, usem uma combinação de texto e código.
#
# Este primeiro trecho de texto pode ser removido de seu trabalho.
#
# O trabalho poderá ser feito em grupos de **no máximo 3 pessoas**
#
# A primeira célula deverá ser, necessariamente, uma versão modificada da célula de texto abaixo
#
# **Regras para submissão trabalho**
#
# O trabalho deverá ser submetido via Moodle até a data de 7 de Dezembro (via atividade específica).
#
# Na atividade um dos membros do grupo deverá submeter o trabalho que deverá incluir, obrigatoriamente:
# 1. Um link para um notebook colab
# 2. Um link para uma gravação do google meet onde o trabalho é apresentado.
#
# ATENÇÃO-> VERIFIQUEM QUE OS LINKS ESTEJAM COM OS ACESSOS CORRETOS
#
# Na apresentação, todos os integrantes deverão estar com a webcam aberta e os membros do grupo devem apresentar, brevemente, o objetivo e desenvolvimento do trabalho.
#
# No início do vídeo, cada aluno deverá se apresentar.
#
# O vídeo deverá conter entre 5-10 minutos.
#
# Confirmar se a base de dados está no formato de download:
# https://sites.google.com/site/gdocs2direct/home
#
# Citem no notebook a origem da base de dados (caso você esteja usando uma).

# %% [markdown]
# Projeto Final de BCC
#
# **Grupo:**
#
# Flavia Aparecida de Morais Clapis; 11202112021; flavia.clapis@aluno.ufabc.edu.br; TNA10BIS0005-15SB
#
# Rodrigo Danilo R. De Carvalho; 21052613; rodrigo.danilo@aluno.ufabc.edu.br; TNA10BIS0005-15SB
#
# Matheus Santin; RA; EMAIL; TNA10BIS0005-15SB
#
# Wesley Café Calazans; 11202131858; ew.cafe@aluno.ufabc.edu.br; TNA10BIS0005-15SB
#
# **Objetivo do Projeto:**
#
# Neste item vocês devem descrever, brevemente, o objetivo do projeto de vocês. Pode ser uma descrição entre 5 a 10 linhas
#
# **Conceitos aprendidos e utilizados no projeto:**
#
# *É importante que vocês indiquem quais conceitos aprendidos serão utilizados no projeto de vocês. Da lista abaixo, destaquem (sublinhando ou deixando em negrito) os conceitos que vocês usarão. O projeto precisa utilizar, obrigatoriamente, pelo menos quatros dos conceitos abaixo*
#
#
# *   Manipulação de Base de Dados
# *   Representação Gráfico de Funções
# *   Estatística Descritiva
# *   Correlação e Regressão
# *   Programação Sequencial
# *   Programação Condicional
# *   Estruturas de Repetição
#
#
# Caso vocês optem por usar uma base de dados disponível, por favor já incluam o link nesta descrição.

# %% [markdown]
# Por favor, na célula acima, deixem apenas as informações pedidas. O projeto de vocês deve começar a partir desta célula. A partir daqui, vocês podem misturar e combinar células de texto e código.
#
# Sempre expliquem o que cada célula está fazendo, seja por meio de texto ou por meio de comentários no código. Por exemplo:

# %%
#Nesta primeira célula, iremos importar as bibliotecas necessárias para nosso projeto

# import numpy as np
# import pandas as pd

# %% [markdown]
# # Informações que temos sobre a MegaSena🤑
#
# Site da Mega Sena - http://loterias.caixa.gov.br/wps/portal/loterias/landing/megasena/
#
# ### Probabilidade de Ganhar um jogo
#
# ![Sem título.png](data:image/png;base64,...)
#
#
# ###Quantidade de premios a receber acertando
# ![image.png](data:image/png;base64,...)
#
# ###Como jogar
# A Mega-Sena paga milhões para o acertador dos 6 números sorteados. Ainda é possível ganhar prêmios ao acertar 4 ou 5 números dentre os 60 disponíveis no volante de apostas. Para realizar o sonho de ser o próximo milionário, você deve marcar de 6 a 15 números do volante, podendo deixar que o sistema escolha os números para você (Surpresinha) e/ou concorrer com a mesma aposta por 2, 4 ou 8 concursos consecutivos (Teimosinha).
#
# ###Sorteios
# Os sorteios da Mega-Sena são realizados duas vezes por semana, às quartas e aos sábados. Para adequar o número do concurso da Mega da Virada, que deve ter final 0 ou 5 foram criadas as Mega-Semanas que são exclusividade da Mega-Sena. Os sorteios ocorrem em datas predeterminadas ao longo do ano. Na ocasião são realizados três concursos semanais, às terças, quintas e sábados. Confira no cronograma de sorteio ou em Comunicados Importantes.
#
# ###Premiação
# O prêmio bruto corresponde a 43,35% da arrecadação. Dessa porcentagem:
#
#     35% são distribuídos entre os acertadores dos 6 números sorteados (Sena);
#
#     19% entre os acertadores de 5 números (Quina);
#
#     19% entre os acertadores de 4 números (Quadra);
#
#     22% ficam acumulados e são distribuídos aos acertadores dos 6 números nos concursos de final 0 ou 5.
#
#     5% ficam acumulados para a primeira faixa - sena - do último concurso do ano de final 0 ou 5 (Mega da Virada).
#
#
# ###Concurso Especial - Mega da Virada
# O último concurso da Mega-Sena de final 0 ou 5 de cada ano civil, que tem a denominação comercial Mega da Virada, obedece às seguintes regras:
#
# **Prazo de comercialização:**
#
# Durante os meses de novembro e dezembro, com captação de apostas independente e concomitante com os demais concursos da modalidade, utilizando-se de volantes específicos (a CAIXA informará com antecedência a data do início das vendas e o número do concurso da Mega da Virada, que será sorteado no dia 31/12).
#
# **Distribuição do valor destinado ao pagamento dos prêmios:**
#
# 62% - primeira faixa - seis acertos (sena);
#
# 19% - segunda faixa - cinco acertos (quina);
#
# 19% - terceira faixa - quatro acertos (quadra).
#
# **Composição da primeira faixa de premiação (sena):**
#
# - 62% do percentual destinado a prêmios, de acordo com a arrecadação do respectivo concurso;
#
# - O total acumulado para o último concurso de final zero ou cinco do ano civil;
#
# - O total acumulado para o concurso de final zero ou cinco;
#
# - O total acumulado na primeira faixa (sena) do concurso anterior, quando houver.
#
# **Critério de acumulação:**
#
# - Não existindo apostas premiadas com seis números (sena), o prêmio será rateado entre os acertadores de cinco números (quina);
#
# - Não existindo apostas premiadas com seis e cinco números, o prêmio será rateado entre os acertadores de quatro números (quadra);
#
# - Não existindo apostas premiadas em quaisquer faixas de premiação, os valores acumulam para o concurso seguinte, nas respectivas faixas.
#
# ###Bolão
#
# O Bolão Caixa é a possibilidade que o apostador tem de realizar apostas em grupo. Basta preencher o campo próprio no volante ou solicitar ao atendente da lotérica. Você também pode comprar cotas de bolões organizados pelas Unidades Lotéricas. Neste caso, poderá ser cobrada uma Tarifa de Serviço adicional de até 35% do valor da cota. Na Mega-Sena, os bolões têm preço mínimo de R$ 10,00. Porém, cada cota não pode ser inferior a R$ 5,00. É possível realizar um bolão de no mínimo 2 e no máximo 100 cotas. É permitida a realização de no máximo 10 apostas por Bolão. Em caso de Bolão com mais de uma aposta, todas elas deverão conter a mesma quantidade de números de prognósticos.
#
# ![image.png](data:image/png;base64,...)
#
# ***Arrecadação***
# Quem joga na Mega-Sena tem milhões de motivos para apostar e milhões de brasileiros para ajudar. Parte do valor arrecadado com as apostas é repassada ao governo federal, que pode, então, realizar investimentos nas áreas de saúde, segurança, cultura e esporte, beneficiando toda a população.
#
# ![image.png](data:image/png;base64,...)
#
# *informações tiradas do site da [Mega Sena]( http://loterias.caixa.gov.br/wps/portal/loterias/landing/megasena/)*

# %% [markdown]
# ##Dados Mega Sena
#
# os dados vão de 11/03/1996 a 27/11/2021
#
# https://drive.google.com/file/d/1K-1_EuvTL-AbzvNMQA-o-ZQusMn5Qyss/view?usp=sharing
#
# Infor
#
# **Concurso**	-- Numero do concurso
#
# **Local**	-- Local onde o sorteio foi realizado (não confundir com local do ganhador)
#
# **Data do Sorteio** -- Data em que o sorteio foi realizado
#
# **Coluna 1**	-- 1º Dezena sorteada
#
# **Coluna 2**	-- 2º Dezena sorteada
#
# **Coluna 3**	-- 3º Dezena sorteada
#
# **Coluna 4**	-- 4º Dezena sorteada
#
# **Coluna 5**	-- 5º Dezena sorteada
#
# **Coluna 6**	-- 6º Dezena sorteada
#
# **Ganhadores Faixa 1** -- Quantas pessoas ganharam o prêmio principal (mega)
#
# **Ganhadores Faixa 2**	-- Quanstas pessoas ganharam a quina
#
# **Ganhadores Faixa 3**	-- Quantas pessoas ganharam a quadra
#
# **Rateio Faixa 1**	-- Quanto cada pessoa recebeu da mega
#
# **Rateio Faixa 2**	-- Quanto cada pessoa recebeu na quina
#
# **Rateio Faixa 3**	-- Quanto cada pessoa recebeu na quadra
#
# **Cidade**	-- Estado da pessoa ganhadora
#
# **Valor Arrecadado**	-- Valor arrecadado para o proximo concurso
#
# **Estimativa para o próximo concurso**
#
# **Valor Acumulado Próximo Concurso**
#
# **Acumulado** -- O sorteio estava acumulado?
#
# **Sorteio Especial** -- É um sorteio da mega da virada?
#
# **Observação**

# %% [markdown]
# # Perguntas que queremos responder:
#
# * Qual o estado com maior numero de ganhadores da Mega Sena? **(fazendo)**
# * Em qual cidade foi sorteado o maior valor? **(fazendo)**
# ---
# * Quais os 6 números mais sorteados? (não necessariamentes na mesma aposta) **(trabalhando nisso - wesley)**
# * Quais os 6 números menos sorteados? (não necessariamentes na mesma aposta) **(trabalhando nisso - wesley)**
# * Existe algum numero que nunca saiu no sorteio comum? E na Mega da Virada? **(Partcialmente respondido)**
# ---
# * Qual a média do premio pago para cada faixa (sena, quina e quadra)? **(respondida)**
# * Qual a média do premio pago em jogos especiais (mega da virada)? **(respondida)**
# ---
# * Em média por quantas rodadas um jogo fica acumulado?
# * Qual foi o jogo com o maior numero de rodadas acumuladas? Quantas rodadas?
# ---
# * Quantos jogos é necessário fazer para ter certeza da vitória?
# * Quantos anos em média uma pessoa demoraria para ganhar jogando sempre os mesmos números?
# * Qual a média do valor gasto em apostas por ano?
# ---
# * Quantos reais já foram distribuidos em premios até hoje? **(respondida)**
# * Quantos reais em impostos já foram pagos atravez da Mega Sena? **(respondida)**

# %%
#importando bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import heapq

# %%
#carregando base de dados
#a base foi retirada do site oficial da caixa, com informações sobre a mega sena
url = 'https://drive.google.com/file/d/1K-1_EuvTL-AbzvNMQA-o-ZQusMn5Qyss/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+ url.split('/')[-2]

megaSena = pd.read_csv(path)

# %%
megaSena.head()
#Não vale a pena fazer dropna para tirar os NaN da Observação (existem poucos concursos com observações, geralmente quando ganhador principal fez o jogo Online)
# Out:
#   Concurso               Local  ... Sorteio Especial  Observação
# 0        1        Brasília, DF  ...              SIM         NaN
# 1        2  Belo Horizonte, MG  ...              SIM         NaN
# 2        3        Brasília, DF  ...              SIM         NaN
# 3        4     Santo André, SP  ...              SIM         NaN
# 4        5        Brasília, DF  ...              SIM         NaN
#
# [5 rows x 22 columns]

# %%
#renomeando colunas
megaSena.columns = ['concurso', 'localSorteio', 'dataSorteio', 'num1', 'num2', 'num3', 'num4', 'num5', 'num6', 'ganhadorSena', 'ganhadorQuina', 'ganhadorQuadra', 'rateioSena', 'rateioQuina', 'rateioQuadra', 'ufGanhadorSena', 'valorArrecadado', 'estimativaPremioProximoConcurso', 'acumuladoProximoConcurso', 'estavaAcumulado', 'sorteioEspecial', 'obs']
megaSena.head()
# Out:
#   concurso        localSorteio dataSorteio  ...  estavaAcumulado  sorteioEspecial  obs
# 0        1        Brasília, DF  11/03/1996  ...              SIM              SIM  NaN
# 1        2  Belo Horizonte, MG  18/03/1996  ...              NAO              SIM  NaN
# 2        3        Brasília, DF  25/03/1996  ...              NAO              SIM  NaN
# 3        4     Santo André, SP  01/04/1996  ...              SIM              SIM  NaN
# 4        5        Brasília, DF  08/04/1996  ...              SIM              SIM  NaN
#
# [5 rows x 22 columns]

# %%
megaSena.describe()
# Out:
#               num1  ...  acumuladoProximoConcurso
# count  2432.000000  ...              2.432000e+03
# mean      8.615132  ...              2.022658e+07
# std       7.004487  ...              2.460358e+07
# min       1.000000  ...              0.000000e+00
# 25%       3.000000  ...              0.000000e+00
# 50%       7.000000  ...              8.068430e+06
# 75%      12.000000  ...              3.769411e+07
# max      50.000000  ...              1.390996e+08
#
# [8 rows x 15 columns]

# %% [markdown]
# ### Qual o estado com maior numero de ganhadores da Mega Sena?

# %%
local = megaSena[['localSorteio', 'concurso']]
local.groupby('localSorteio').count().sort_values(by='concurso', ascending=False)
# Out:
#                       concurso
# localSorteio
# SÃO PAULO, SP              401
# OSASCO, SP                 101
# Brasília, DF               100
# BRASÍLIA, DF                29
# IPAMERI, GO                 23
# ...                        ...
# JAGUAQUARA, BA               1
# JACUPIRANGA, SP              1
# JACOBINA, BA                 1
# JACIARA, MT                  1
# Águas de Lindóia, SP         1
#
# [799 rows x 1 columns]

# %% [markdown]
# ### Qual o concurso com maior número de ganhadores?

# %%
num_ganhadores = megaSena[['ganhadorSena', 'concurso']]
num_ganhadores.groupby('ganhadorSena').count().sort_values(by='ganhadorSena', ascending=False)
# Out:
#               concurso
# ganhadorSena
# 52.0                 1
# 17.0                 1
# 15.0                 1
# 7.0                  1
# 6.0                  2
# 5.0                  3
# 4.0                 12
# 3.0                 23
# 2.0                 97
# 1.0                414
# 0.0               1877

# %% [markdown]
# ###Em média quantos jogos ficaram acumulados por mais de uma rodada, no mínimo?

# %%
quant_acumulado = megaSena.query("estavaAcumulado == 'SIM'")
quant_acumulado2 = quant_acumulado.query("acumuladoProximoConcurso > 0")

contagem_sim = quant_acumulado2.shape[0]
contagem_total = megaSena.shape[0]

print("A média de jogos que acumularam por mais de uma semana é de:", contagem_sim/contagem_total)
# Out:
# A média de jogos que acumularam por mais de uma semana é de: 0.4459515002055076

# %% [markdown]
# ### Qual foi o maior valor já sorteado na Sena e em qual cidade foi sorteado?

# %%
#sorteiomaximo = megaSena.sort_values(by="Rateio Faixa 1", ascending=False)
#print('O maior prêmio da sena foi de R$', megaSena['rateioSena'].max(), '\nE o ganhador(a) era de', megaSena[['localSorteio']].loc[megaSena['rateioSena'] == valormax])

# %%
megaSena['num1'].hist()
megaSena['num2'].hist()
megaSena['num3'].hist()
megaSena['num4'].hist()
megaSena['num5'].hist()
megaSena['num6'].hist()

# %% [markdown]
# ### Quantos reais já foram distribuidos em premios até hoje?

# %%
premios = megaSena[['concurso', 'ganhadorSena', 'ganhadorQuina', 'ganhadorQuadra', 'rateioSena', 'rateioQuina', 'rateioQuadra', 'ufGanhadorSena', 'valorArrecadado', 'sorteioEspecial']]
premios.head()
# Out:
#   concurso  ganhadorSena  ...  valorArrecadado  sorteioEspecial
# 0        1           0.0  ...              0.0              SIM
# 1        2           1.0  ...              0.0              SIM
# 2        3           2.0  ...              0.0              SIM
# 3        4           0.0  ...              0.0              SIM
# 4        5           0.0  ...              0.0              SIM
#
# [5 rows x 10 columns]

# %%
premioSena = (premios['rateioSena']) * (premios['ganhadorSena'])
premioQuina = (premios['rateioQuina']) * (premios['ganhadorQuina'])
premioQuadra = (premios['rateioQuadra']) * (premios['ganhadorQuadra'])
premioQuadra
# Out:
# 0        665703.36
# 1        937588.08
# 2        651975.61
# 3        597569.28
# 4        521165.47
#            ...
# 2428    2809265.10
# 2429    5100378.43
# 2430    2339125.92
# 2431    3025880.84
# 2432           NaN
# Length: 2433, dtype: float64

# %%
premios = [premioQuadra, premioQuina, premioSena]
premios = pd.DataFrame(list(zip(premioSena, premioQuina, premioQuadra)), columns=['premioSena', 'premioQuina', 'premioQuadra'])
premios = premios.dropna()
premios.head()
# Out:
#    premioSena  premioQuina  premioQuadra
# 0        0.00    665701.64     665703.36
# 1  2307162.23    937561.30     937588.08
# 2   782385.02    651987.66     651975.61
# 3        0.00    597567.36     597569.28
# 4        0.00    521173.80     521165.47

# %%
len(premios['premioSena'])
# Out:
# 2432

# %%
somatoriaSena = round(premios['premioSena'].sum(), 2)
somatoriaQuina = round(premios['premioQuina'].sum(), 2)
somatoriaQuadra = round(premios['premioQuadra'].sum(), 2)
somatoriaTotal = somatoriaSena + somatoriaQuina + somatoriaQuadra

porcentagemSena = round((somatoriaSena*100)/somatoriaTotal, 5)
porcentagemQuina = round((somatoriaQuina*100)/somatoriaTotal,5)
porecentagemQuadra = round((somatoriaQuadra*100)/somatoriaTotal,5)

porC= porcentagemSena + porcentagemQuina + porecentagemQuadra

print(somatoriaSena, somatoriaQuina, somatoriaQuadra)
print('Somatoria das porcentagens:',porC)
print('A Mega Sena já distribuiu ', 'R$',somatoriaTotal, '\nSendo que a Sena é responsalvel por ', porcentagemSena, '\nA Quina por ', porcentagemQuina, ' e a Quadra por ', porecentagemQuadra)
# Out:
# 16405460035.45 5342332728.0 7063971967.57
# Somatoria das porcentagens: 100.0
# A Mega Sena já distribuiu  R$ 28811764731.02
# Sendo que a Sena é responsalvel por  56.94014
# A Quina por  18.54219  e a Quadra por  24.51767

# %% [markdown]
# A Mega Sena desde a sua criação já distribuiu de R\$ 28.811.764.731,02 ***(vinte e oito bilhões oitocentos e onze milhões setecentos e sessenta e quatro mil setecentos e trinta e um reais e dois centavos)*** até a data 27 de Novembro de 2021desconsiderando os impostos, se considerado os 30% de impostos a Mega Sena distribuiu R\$ 20.168.235.311,71 ***(vinte bilhões cento e sessenta e oito milhões duzentos e trinta e cinco mil trezentos e onze reais e setenta e um centavos)*** em premios

# %% [markdown]
# ### Quanto em imposto já foi pago na mega sena?

# %%
impostoRecolhido = somatoriaTotal*.3 #É recolhido 30% do valor pago no premio para o Imposto de Renda
premioRecebido = somatoriaTotal - impostoRecolhido

print(round(impostoRecolhido, 2), round(premioRecebido, 2))
# Out:
# 8643529419.31 20168235311.71

# %%
impostoAno = round(impostoRecolhido/25, 2)
premioAno = round(premioRecebido/25, 2)

print(impostoAno, premioAno)
# Out:
# 345741176.77 806729412.47

# %% [markdown]
# Se fosse distribuido integralmente (sem desconto de imposto) para um unica pessoa, ela seria a **13º Pessoa Mais rica do Brasil** e a **622º Mais rica do mundo em 2021**, com **US\$ 5,02 bilhões**. Caso fosse descontado o imposto esta pessoa seria a ***16º Mais rica do Brasil*** e a ***859º Mais rica do Mundo***, com US\$ 3.56 bilhões
#
# Fonte:<https://comoinvestir.thecap.com.br/quem-sao-os-bilionarios-brasileiros-de-2021/>

# %% [markdown]
# ### Qual a média do premio pago para cada faixa (sena, quina e quadra)?

# %%
premios = megaSena[['concurso', 'ganhadorSena', 'ganhadorQuina', 'ganhadorQuadra', 'rateioSena', 'rateioQuina', 'rateioQuadra', 'ufGanhadorSena', 'valorArrecadado', 'sorteioEspecial']]
premios.head()
# Out:
#   concurso  ganhadorSena  ...  valorArrecadado  sorteioEspecial
# 0        1           0.0  ...              0.0              SIM
# 1        2           1.0  ...              0.0              SIM
# 2        3           2.0  ...              0.0              SIM
# 3        4           0.0  ...              0.0              SIM
# 4        5           0.0  ...              0.0              SIM
#
# [5 rows x 10 columns]

# %%
mediaSena = premios['rateioSena'].mean()
mediaQuina = premios['rateioQuina'].mean()
mediaQuadra = premios['rateioQuadra'].mean()

print('O premio medio da Sena é: R$ ',round(mediaSena, 2),'\nO premio medio da Quina é: R$ ', round(mediaQuina, 2),'\nO premio medio da Quina é: R$ ', round(mediaQuadra, 2))
# Out:
# O premio medio da Sena é: R$  4904851.81
# O premio medio da Quina é: R$  26124.48
# O premio medio da Quina é: R$  451.88

# %% [markdown]
# ### Qual a média do premio pago em jogos especiais (ex. mega da virada)?

# %%
#df_mask=df['col_name']=='specific_value'

mascaraFiltro = premios['sorteioEspecial'] == 'SIM'
concursoEspecial = premios[mascaraFiltro]

concursoEspecial.head()
# Out:
#   concurso  ganhadorSena  ...  valorArrecadado  sorteioEspecial
# 0        1           0.0  ...              0.0              SIM
# 1        2           1.0  ...              0.0              SIM
# 2        3           2.0  ...              0.0              SIM
# 3        4           0.0  ...              0.0              SIM
# 4        5           0.0  ...              0.0              SIM
#
# [5 rows x 10 columns]

# %%
mediaSenaEspecial = concursoEspecial['rateioSena'].mean()
mediaQuinaEspecial = concursoEspecial['rateioQuina'].mean()
mediaQuadraEspecial = concursoEspecial['rateioQuadra'].mean()

print('O premio medio da Sena Especial é: R$ ',round(mediaSenaEspecial, 2),'\nO premio medio da Quina Especial é: R$ ', round(mediaQuinaEspecial, 2),'\nO premio medio da Quadra Especial é: R$ ', round(mediaQuadraEspecial, 2))
# Out:
# O premio medio da Sena Especial é: R$  4804802.61
# O premio medio da Quina Especial é: R$  26116.56
# O premio medio da Quadra Especial é: R$  451.52

# %%
diferencaSena = mediaSenaEspecial - mediaSena
diferencaQuina = mediaQuinaEspecial - mediaQuina
diferencaQuadra = mediaQuadraEspecial - mediaQuadra

print('A diferença entro o sorteio especial e o comum da Sena é: R$ ',round(diferencaSena, 2),'\nA diferença entro o sorteio especial e o comum da Quina é: R$ ', round(diferencaQuina, 2),'\nA diferença entro o sorteio especial e o comum da Quadra é: R$ ', round(diferencaQuadra, 2))
# Out:
# A diferença entro o sorteio especial e o comum da Sena é: R$  -100049.2
# A diferença entro o sorteio especial e o comum da Quina é: R$  -7.92
# A diferença entro o sorteio especial e o comum da Quadra é: R$  -0.36

# %% [markdown]
# A diferença entre os premios dos sorteios comuns VS dos sorteios especiais é bem pequena, na Sena é onde temos a maior diferença (R$ 100.049,20)

# %%
#Tentativa de selecionar apenas os sorteios da Mega da virada (a partir de 31/12/2008, sendo realizado todo dia 31/12)


#'(31)(\/)(12)(\/)(20)((0[8-9])|[1-2][0-9])'
#mascaraFiltro = megaSena['dataSorteio'] == '31/12/2008'  '(31)(\/)(12)(\/)(20)[1-2][0-9])'
#megaVirada = megaSena[mascaraFiltro].filter(r'(31)(\/)(12)(\/)(20)((0[8-9])|[1-2][0-9])')

# %% [markdown]
# ###Existe uma sequencia de jogos que se repetem mais de uma vez? Se sim qual a sequência e quantas vezes ela saiu?
# ###Quais os 6 números mais sorteados? (não necessariamentes na mesma aposta)
# ###Quais os 6 números menos sorteados? (não necessariamentes na mesma aposta)
# ###Existe algum numero que nunca saiu no sorteio comum?

# %%
numerosSorteados = megaSena[['num1', 'num2', 'num3', 'num4', 'num5', 'num6']]
numerosSorteados.head()
# Out:
#    num1  num2  num3  num4  num5  num6
# 0   4.0   5.0  30.0  33.0  41.0  52.0
# 1   9.0  37.0  39.0  41.0  43.0  49.0
# 2  10.0  11.0  29.0  30.0  36.0  47.0
# 3   1.0   5.0   6.0  27.0  42.0  59.0
# 4   1.0   2.0   6.0  16.0  19.0  46.0

# %%
numerosSorteados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2433 entries, 0 to 2432
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   num1    2432 non-null   float64
#  1   num2    2432 non-null   float64
#  2   num3    2432 non-null   float64
#  3   num4    2432 non-null   float64
#  4   num5    2432 non-null   float64
#  5   num6    2432 non-null   float64
# dtypes: float64(6)
# memory usage: 114.2 KB

# %%
numerosSorteados.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb0b1d5dd0>,
# ...
#       dtype=object)

# %%
listaDezenas = []
dez1 = numerosSorteados['num1'].tolist()
dez2 = numerosSorteados['num2'].tolist()
dez3 = numerosSorteados['num3'].tolist()
dez4 = numerosSorteados['num4'].tolist()
dez5 = numerosSorteados['num5'].tolist()
dez6 = numerosSorteados['num6'].tolist()

for num in dez1:
  listaDezenas.append(num)

for num in dez2:
  listaDezenas.append(num)

for num in dez3:
  listaDezenas.append(num)

for num in dez4:
  listaDezenas.append(num)

for num in dez5:
  listaDezenas.append(num)

for num in dez6:
  listaDezenas.append(num)

len(listaDezenas)
# Out:
# 14598

# %%
listaDezenas = [x for x in listaDezenas if np.isnan(x) == False]
len(listaDezenas)
# Out:
# 14592

# %%
def remove_repetidos(lista):
    l = []
    for i in lista:
        if i not in l:
            l.append(i)
    l.sort()
    return l

listaNumeros = remove_repetidos(listaDezenas)


print('Todos os',len(listaNumeros), 'já sairam no universo de sorteios')
# Out:
# Todos os 60 já sairam no universo de sorteios

# %%
repeticaoN = []
repeticao = {}
for n in listaNumeros:
  repeticaoN = (listaDezenas.count(n))
  repeticao[n]= n, repeticaoN
  

repeticaoDezena = pd.DataFrame.from_dict(repeticao, orient='index')
repeticaoDezena.columns = ['dezenas','repetição']

dezena = repeticaoDezena['dezenas']
repeticao = repeticaoDezena['repetição']

repeticao.sort_values(ascending=True).plot(kind='barh', 
                                           title='Dezenas por ordem de sorteio', 
                                           figsize=(10,25), 
                                           fontsize=14, 
                                           legend=True, 
                                           color='green',
                                           ylabel='Repetição',
                                           xlabel='Dezena',                                           
                                           )

# %%
repeticao.sort_values(ascending=False).head(6).plot(kind='barh', 
                       title='Numeros mais sorteados', 
                       figsize=(10,5), 
                       legend=True, 
                       color='green',
                       xlabel='Dezenas',
                       ylabel='Repetição'
                       )

# %%
Dezenas.head()
# Out:
#    numeros
# 0      4.0
# 1      9.0
# 2     10.0
# 3      1.0
# 4      1.0

# %%
repeticaoDezena.head()
# Out:
#      dezenas  repetição
# 1.0      1.0        233
# 2.0      2.0        247
# 3.0      3.0        225
# 4.0      4.0        263
# 5.0      5.0        266
